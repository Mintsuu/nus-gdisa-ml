# %% [markdown]
# # Question 1
#
# ## The table below is the revenue of your client Loving and Caring (LC) Pte Ltd revenue progress based on the last 5 quarter revenues.
#
# ![image.png](attachment:image.png)
#
# ## You are requested to develop python for the following questions and using only <b>NumPy Library<b>.

# %% [markdown]
# ### Q1a Write a python code snippet to print out that quarter number that has the highest revenue (Number only is enough).(Hint: use the argmax() of Numpy)

# %%
# Q1a Code here

# %% [markdown]
# ### Q1b	Write python code snippet to calculate the percentage change in revenue from the previous quarter and print out the specific quarter number (Number only is enough) with the highest percentage change in revenue from the previous quarter.
# ### (Hint: You may use a numpy function called ‘numpy.diff (input_array)’
#    ### import numpy as np
#    ### x = np.array([1, 2, 4, 7, 0])
#    ### print(np.diff(x))
#    ### #Output = [ 1,  2,  3, -7]
# ### )

# %%
# Q1b Code here

# %% [markdown]
# # Question 2
#
# ## As a data analyst in a delivery company called The Logistic Company (TLC) .
# ## You are assigned to develop python codes for supply chain management, operations, analysis and predict the future trends.
#
# ## Use only prediction algorithm that you have learnt in Day 1 to Day 5.
# ## For data processing use only NumPY and Pandas libraries.
# ## Below is the transaction dataset of TLC.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question 2a
# ###   Assumed that the shipment date is ‘2023-10-24’ for all above orders.
# ### You need to calculate the ‘delivery lead time’ which is in ‘days’ by (Delivery date – Shipment date).
# ### Write a Python code to convert the above sample data with order_id, city, delivery_date, order_amount, and respective ‘delivery_lead_time’ (in day) in a dataframe.
# ### (Hint: You may need to use the command below to change the ‘day’ format to an integer.)
# ### # To convert difference of dates into ‘days’
# ### df["dates"] = df["dates"].dt.days.astype('int16')

# %%
# Question 2a code

# %% [markdown]
# ### Question 2b
# ### Based on the DataFrame that you have created in Question 2a,
# ### i.  Write Python codes to find an average of delivery lead time respective to each city using the above-created dataframe and the highest average time and the corresponding city.
# ### ii. Write Python code to print out the city with the highest average delivery lead time and number of days.

# %%
# Question 2b code

# %% [markdown]
# ### Question 2c
# ### i.  Write Python code to train a suitable machine learning model to predict the delivery lead time based on the order amount using the above sample data.
# ###     (You are NOT required to split the date for training and testing.)
# ###
# ### ii. Include a code snippet to predict the delivery lead time for a new order amount of 600 using the trained model.

# %%
# Question 2c

# %% [markdown]
# ### Question 2d
# You have been assigned to another project. In that project, ensuring on-time delivery is crucial for customer satisfaction and maintaining a good reputation. However, various factors can lead to delays, making it challenging to predict on-time deliveries accurately. A classification model can be used to predict on-time deliveries based on historical data.
# ![image.png](attachment:image.png)
#
# Assume that you have historical shipment data containing features as below: </br>
# </br>
# •	order_id: Unique identifier for each order                                  </br>
# •	origin: Origin warehouse location (categorical)                             </br>
# •	destination: Destination city (categorical)                                 </br>
# •	order_date: Date the order was placed (datetime)                            </br>
# •	shipment_date: Date the shipment was dispatched (datetime)                  </br>
# •	delivery_date: Date the order was delivered (datetime)                      </br>
# •	distance: Distance between origin and destination (numerical)               </br>
# •	order_size: Number of items in the order (numerical)                        </br>
# •	weather_condition_during_shipment: Categorical variable indicating weather  </br>  conditions (sunny, rainy, etc.)                                                 </br>
# •	on_time_delivery (target variable): Binary variable indicating whether the  </br>  delivery was on time (True) or delayed (False)                                  </br>
# </br>
# The categorical features are required to be encoded accordingly. You may utilize the LabelEncoder class provided by the Sklearn library. Refer below for the documentation of the LabelEncoder class. You may also use any other relevant encoding approach.
#
# Returns an instance of itself.
# Example-
# le = preprocessing.LabelEncoder() </br>
# #Transform to encoded labels </br>
# df.column_to_encoded = le.fit_transform(df['column_to_encoded'])

# %% [markdown]
# ### Question 2d(i)
# Identify a suitable classification model to predict the delivery status (on time (True) or delayed (False)).

# %% [markdown]
# ### Write your answer

# %% [markdown]
# ### Question 2d(ii)
# State at least one brief reason why you choose such a classification model for this project.

# %% [markdown]
# ### Write your answer

# %% [markdown]
# ### Question 2d (iii)
# Write Python code to encode the categorical features and clean the dataset accordingly for training and testing the suggested classification model. After cleaning data, you are required to train the classification model to predict the delivery status. You also need to evaluate the trained model’s performance by printing its accuracy using an appropriate dataset.

# %%
## Question 2d (iii) Code here

# %% [markdown]
# ### Question 3
# Using historical data, the company wants to build a decision tree to predict whether a product should be restocked or not. The dataset of a sample product (product A) is provided. Assume that:
# -	Product A inventory information is found in the picture below.
# ![image.png](attachment:image.png)
# <br>
# You are required to develop a decision tree model that predicts the status of restocking or not restocking Product A. The features of the dataset require to be encoded with dummy variables accordingly before training the model.

# %% [markdown]
# ### Question 3a
#
# Write Python code to load, prepare, encode data, and train a decision tree model to predict the restocking status. <br>
# You are NOT required to split the dataset for training and testing in this case.

# %%
### Question 3a code here

# %% [markdown]
# ### Question 3b
#
# Based on the Decision Tree diagram generated from the above, what would be the prediction for the following attributes ?
#
# -	Demand Forecast: Low
# -	Current Stock Level: Low
# -	Supplier Reliability: High
# -	Lead Time: Short

# %% [markdown]
# ### Write your answer here
